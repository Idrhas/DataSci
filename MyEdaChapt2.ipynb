# %%
# !pip install faker
# Out:
# Requirement already satisfied: faker in c:\users\abooabdillah\anaconda3\lib\site-packages (5.4.0)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\abooabdillah\anaconda3\lib\site-packages (from faker) (2.8.1)
# Requirement already satisfied: text-unidecode==1.3 in c:\users\abooabdillah\anaconda3\lib\site-packages (from faker) (1.3)
# Requirement already satisfied: six>=1.5 in c:\users\abooabdillah\anaconda3\lib\site-packages (from python-dateutil>=2.4->faker) (1.15.0)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x000001E6A6A0B0A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/radar/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x000001E6A69FEF40>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/radar/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x000001E6A69FEE20>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/radar/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x000001E6A69FEB80>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/radar/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x000001E6A69FEC10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/radar/
# ERROR: Could not find a version that satisfies the requirement radar (from versions: none)
# ERROR: No matching distribution found for radar

# %%
# !pip install radar
# Out:
# Collecting radar
#   Downloading radar-0.3.tar.gz (4.5 kB)
# Building wheels for collected packages: radar
#   Building wheel for radar (setup.py): started
#   Building wheel for radar (setup.py): finished with status 'done'
#   Created wheel for radar: filename=radar-0.3-py3-none-any.whl size=5014 sha256=886cff3f207b8c1e3ac3edcb4633de5d82633d0a828abad317f1470068f0f113
#   Stored in directory: c:\users\abooabdillah\appdata\local\pip\cache\wheels\24\09\76\8409218c4f1404ab6adf78a3ff85b04187a3aebd37c862304d
# Successfully built radar
# Installing collected packages: radar
# Successfully installed radar-0.3

# %%
from faker import Faker
fake = Faker()

# %%
import datetime
import math
import pandas as pd
import random 
import radar 
from faker import Faker
fake = Faker()

def generateData(n):
  listdata = []
  start = datetime.datetime(2019, 8, 1)
  end = datetime.datetime(2019, 8, 30)
  delta = end - start
  for _ in range(n):
    date = radar.random_datetime(start='2019-08-1', stop='2019-08-30').strftime("%Y-%m-%d")
    price = round(random.uniform(900, 1000), 4)
    listdata.append([date, price])
  df = pd.DataFrame(listdata, columns = ['Date', 'Price'])
  df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
  df = df.groupby(by='Date').mean()

  return df

# %%
df = generateData(50)
df.head(10)
# Out:
#                  Price
# Date
# 2019-08-01  921.582700
# 2019-08-02  912.949100
# 2019-08-03  951.668867
# 2019-08-04  937.832600
# 2019-08-05  911.994600
# 2019-08-07  996.395700
# 2019-08-09  974.847900
# 2019-08-10  941.736900
# 2019-08-12  935.607067
# 2019-08-13  954.385125

# %%
df.to_csv(r'stock.csv')

# %%
#imprt matplotlib library

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (14, 10)

# %%
# plot graph

plt.plot(df)
